# %% [markdown]
# # 🧪 Лабораторна робота №1
# ## Тема: Основи Python – змінні, введення-виведення, типи даних, базові обчислення
#
# ## 🎯 Мета роботи:
# - Ознайомитися із середовищем Jupyter Notebook
# - Навчитися **працювати** зі змінними та базовими типами даних
# - Використовувати `print()`, `input()`, `type()`
# - Виконувати прості арифметичні операції

# %% [markdown]
# ---

# %% [markdown]
# ## 📖 Розширені теоретичні відомості

# %% [markdown]
# ### 1️⃣ Інтерпретатор і виконання коду
# - **Python — інтерпретована мова**, тобто кожен рядок виконується послідовно.
# - Якщо трапляється помилка, виконання зупиняється, і ви бачите **трасування (traceback)** з поясненням, що саме пішло не так.

# %% [markdown]
# ### 2️⃣ Змінні та імена змінних
# - **Змінна** – це ім’я, яке вказує на деяке значення в пам’яті.
# - Правила для імені змінної:
#   - Починатися з літери або `_`
#   - Містити лише латинські букви, цифри та `_`
#   - Не бути ключовим словом Python (`if`, `for`, `while`, `class`, `True`, `None` тощо)
# - **Приклади допустимих імен:** `age`, `temperature`, `user_name`
# - **Приклади недопустимих імен:** `123name`, `for`, `user-name`
# - **Поради:**
#   - Використовуйте описові імена, щоб код було легко читати.
#   - Уникайте імен, які збігаються з вбудованими функціями (`print`, `input`).

# %% [markdown]
# ### 3️⃣ Типи даних
# | Тип       | Опис | Приклад |
# |----------|------|---------|
# | `int`   | Цілі числа | `-5`, `0`, `42` |
# | `float` | Числа з плаваючою крапкою | `3.14`, `-0.001` |
# | `str`   | Текстові рядки | `'Python'`, `"Привіт"` |
# | `bool`  | Логічні значення | `True`, `False` |
# | `list`  | Список об’єктів | `[1, 2, 3]` |
# | `dict`  | Словник (ключ:значення) | `{"name": "Ana", "age": 20}` |
#
# Тип можна перевірити за допомогою функції `type(x)`.

# %% [markdown]
# ### 4️⃣ Арифметичні операції
# | Операція | Приклад | Результат |
# |----------|--------|-----------|
# | Додавання | `5 + 3` | `8` |
# | Віднімання | `5 - 3` | `2` |
# | Множення | `5 * 3` | `15` |
# | Ділення | `5 / 3` | `1.666...` |
# | Цілочисельне ділення | `5 // 3` | `1` |
# | Остача від ділення | `5 % 3` | `2` |
# | Степінь | `5 ** 2` | `25` |

# %% [markdown]
# ### 5️⃣ Введення та виведення
#
# - **Введення:**
#   - Функція `input()` завжди повертає **рядок** (`str`).
#   - Щоб працювати з числами, потрібно привести тип.
#   - Приклади:
#     ```python
#     name = input("Введіть ваше ім'я: ")
#     age = int(input("Введіть ваш вік: "))
#     ```
#   - Пояснення:
#     - `name` буде рядком.
#     - `age` буде цілим числом.
#
# - **Виведення:**
#   - Функція `print()` може виводити кілька значень через кому.
#   - Приклад:
#     ```python
#     print("Сума:", 2 + 3)
#     print("Різниця:", 5 - 2)
#     ```
#
# - **Форматування рядків:**
#   1. **f-рядки:**
#      ```python
#      name = "Оля"
#      age = 22
#      print(f"{name} має {age} роки")
#      ```
#   2. **Метод `.format()`:**
#      ```python
#      name = "Оля"
#      age = 22
#      print("{} має {} роки".format(name, age))
#      ```
#   3. **Конкатенація рядків:**
#      ```python
#      name = "Оля"
#      print("Привіт, " + name + "!")
#      ```
# - **Поради:**
#   - Завжди перевіряйте тип введених даних.
#   - Використовуйте зрозумілі повідомлення для користувача.
#   - f-рядки зручні для читання і кодування змінних прямо в текст.

# %% [markdown]
# ### 6️⃣ Корисні поради
# - Використовуйте описові імена змінних, щоб код було легко читати.
# - Уникайте перевизначення вбудованих функцій (наприклад, print = 5).
# - Використовуйте коментарі (# коментар) для пояснення коду.
# - Привчайтеся до відступів: у Python вони визначають структуру коду (блоки if, for, while).

# %% [markdown]
# ### 7️⃣ Поширені помилки початківців
# - Забули привести тип після input() → рядки не можна додавати як числа.
# - Використали українські літери в імені змінної → код може не працювати на іншому комп’ютері.
# - Поділили на нуль → ZeroDivisionError.
# - Перевизначили ім’я функції (input = 10) → далі input() не працює.

# %% [markdown]
# ### 8️⃣ Практичні рекомендації
# - Краще писати код невеликими блоками та перевіряти кожен крок.
# - Використовуйте print() для проміжних результатів, щоб відслідковувати логіку.
# - Для перевірки та експериментів використовуйте Jupyter Notebook – можна виконувати окремі комірки.

# %% [markdown]
# ---

# %% [markdown]
# ## 📝 Завдання 1. Привітання користувача
# Запитайте ім’я та вік користувача. Виведіть привітання у форматі:
# `Привіт, [ім'я]! Тобі [вік] років.`

# %%
# Ваш код тут
name = input("Enter name: ")
age = int(input("Enter age: "))
print(f"Hello, {name}! You are {age} years old.")

# %% [markdown]
# ### 🔢 Завдання:
# 1. Запитайте у користувача його місто та виведіть: `Ти живеш у [місто]`.
# 2. Запитайте ім’я та прізвище, виведіть їх у форматі `Привіт, Прізвище Ім’я!`.
# 3. Запитайте у користувача улюблений колір та виведіть повідомлення з ним.
# 4. Зчитайте рік народження та виведіть, скільки йому буде через 10 років.
# 5. Запитайте 3 рядки й виведіть їх на одному рядку через кому.
# 6. Зробіть так, щоб програма виводила ім’я 3 рази підряд.
# 7. Запитайте у користувача його хобі й виведіть: `Цікаво, що ти любиш [хобі]`.
# 8. Запитайте у користувача його настрій та виведіть його у форматі емодзі.
# 9. Зчитайте ім’я та переведіть його в UPPERCASE.
# 10. Зчитайте прізвище та переведіть його у lowercase.

# %% [markdown]
# ## 📝 Завдання 2. Арифметика
# Зчитайте два числа. Обчисліть і виведіть їх суму, різницю, добуток і частку.

# %%
# Ваш код тут
a = int(input("Введіть перше число: "))
b = int(input("Введіть друге число: "))
print("Сума:", a + b)
print("Різниця:", a - b)
print("Добуток:", a * b)
print("Частка:", a / b)
# Out:
# Введіть перше число:  7
# Введіть друге число:  6
# Сума: 13
# Різниця: 1
# Добуток: 42
# Частка: 1

# %% [markdown]
# ### 🔢 Завдання:
# 1. Обчисліть середнє арифметичне двох чисел.
# 2. Обчисліть залишок від ділення.
# 3. Обчисліть число у квадраті.
# 4. Обчисліть число у кубі.
# 5. Зчитайте три числа та виведіть їх суму.
# 6. Обчисліть модуль числа.
# 7. Обчисліть цілочисельну частку.
# 8. Обчисліть квадратний корінь (через `**0.5`).
# 9. Зчитайте два числа і виведіть більше з них.
# 10. Зчитайте два числа і виведіть менше з них.

# %% [markdown]
# ## 📝 Завдання 3. Квадратне рівняння
# Зчитайте `a`, `b`, `c`. Обчисліть дискримінант `D = b² - 4ac` та виведіть його значення.

# %%
# Ваш код тут
a = float(input("a: "))
b = float(input("b: "))
c = float(input("c: "))
D = b**2 - 4*a*c
print("Дискримінант:", D)

# %% [markdown]
# ### 🔢 Завдання:
# 1. Виведіть тільки корені, якщо D ≥ 0.
# 2. Перевірте, чи рівняння має два корені.
# 3. Якщо D < 0, виведіть повідомлення, що коренів немає.
# 4. Обчисліть суму коренів.
# 5. Обчисліть добуток коренів.
# 6. Обчисліть лише більший корінь.
# 7. Обчисліть лише менший корінь.
# 8. Обчисліть корені з точністю до 3 знаків після коми.
# 9. Реалізуйте розв’язок через `math.sqrt()`.
# 10. Реалізуйте через `cmath` для комплексних коренів.

# %% [markdown]
# ## 📝 Завдання 4. Перетворення температур
# Зчитайте температуру в °C, переведіть у °F за формулою `F = C * 9/5 + 32`.

# %%
# Ваш код тут
C = float(input("Температура в °C: "))
F = C * 9/5 + 32
print("Температура в °F:", F)

# %% [markdown]
# ### 🔢 Завдання:
# 1. Переведіть температуру у Кельвіни.
# 2. Зробіть зворотне перетворення (F → C).
# 3. Переведіть Кельвіни у Цельсії.
# 4. Додайте перевірку, що C ≥ −273.15.
# 5. Додайте округлення до 1 знака.
# 6. Зробіть цикл для перетворення 5 температур підряд.
# 7. Додайте повідомлення, якщо температура нижче нуля.
# 8. Зробіть функцію `c_to_f(c)`.
# 9. Зробіть функцію `f_to_c(f)`.
# 10. Зчитайте список температур та перетворіть всі у °F.

# %% [markdown]
# ## 📝 Завдання 5. Типи змінних
# Створіть кілька змінних різних типів і виведіть їх тип за допомогою `type()`.

# %%
# Ваш код тут
var1 = 10
var2 = 3.14
var3 = "Python"
print(type(var1), type(var2), type(var3))
# Out:
# <class 'int'> <class 'float'> <class 'str'>

# %% [markdown]
# ### 🔢 Завдання:
# 1. Створіть змінну типу `bool` і виведіть її.
# 2. Створіть список із трьох чисел і виведіть його тип.
# 3. Створіть словник із двома ключами.
# 4. Створіть кортеж із трьох рядків.
# 5. Створіть множину з двох елементів.
# 6. Перевірте тип після перетворення `str(123)`.
# 7. Перевірте тип після `float(10)`.
# 8. Перевірте тип після `bool(0)`.
# 9. Перевірте тип після `bool(5)`.
# 10. Перевірте тип після `list("abc")`.

# %% [markdown]
# ## 📝 Завдання 6. Форматування рядків
# Створіть три змінні (ім’я, предмет, оцінка) і виведіть повідомлення:
# `Студент [ім’я] отримав [оцінка] з [предмет]`.

# %%
# Ваш код тут
student = "Андрій"
subject = "Математика"
grade = 95
print(f"Студент {student} отримав {grade} з {subject}")
# Out:
# Студент Андрій отримав 95 з Математика

# %% [markdown]
# ### 🔢 Завдання:
# 1. Виведіть число з двома нулями попереду (наприклад, 007).
# 2. Виведіть число з 3 знаками після коми.
# 3. Використайте `format()` для форматування.
# 4. Використайте конкатенацію рядків.
# 5. Використайте `join()` для об’єднання списку рядків.
# 6. Використайте `rjust()` для вирівнювання по правому краю.
# 7. Використайте `center()` для центрування тексту.
# 8. Використайте `zfill()` для заповнення нулями.
# 9. Використайте `replace()` для заміни символів.
# 10. Використайте `upper()` і `lower()` на рядках.

# %% [markdown]
# ## 📝 Завдання 7. Індекс маси тіла
# Запитайте вагу (кг) і зріст (м), обчисліть ІМТ = вага / зріст² та виведіть результат.

# %%
# Ваш код тут
weight = float(input("Вага (кг): "))
height = float(input("Зріст (м): "))
bmi = weight / (height ** 2)
print("Ваш ІМТ:", bmi)

# %% [markdown]
# ### 🔢 Завдання:
# 1. Додайте класифікацію (норма/надмірна вага).
# 2. Округліть до 1 знака.
# 3. Виведіть повідомлення, якщо ІМТ < 18.5.
# 4. Виведіть повідомлення, якщо ІМТ > 30.
# 5. Запропонуйте ідеальну вагу для заданого зросту.
# 6. Обчисліть ІМТ для кількох людей у циклі.
# 7. Збережіть результат у список.
# 8. Зробіть функцію `calc_bmi(w, h)`.
# 9. Перевірте на від’ємні значення.
# 10. Перевірте на нульовий зріст (виняток).

# %% [markdown]
# ## 📝 Завдання 8. Обмін значень
# Запитайте два числа та поміняйте їх місцями без створення третьої змінної.

# %%
# Ваш код тут
x = int(input("x: "))
y = int(input("y: "))
x, y = y, x
print("Після обміну: x =", x, ", y =", y)

# %% [markdown]
# ### 🔢 Завдання:
# 1. Виконайте обмін через третю змінну.
# 2. Використайте арифметичні операції для обміну.
# 3. Виконайте обмін трьох змінних (x→y, y→z, z→x).
# 4. Виконайте обмін чотирьох змінних.
# 5. Обміняйте два елементи у списку.
# 6. Обміняйте перший і останній елемент списку.
# 7. Використайте `tuple unpacking` для трьох змінних.
# 8. Обміняйте значення, якщо x < y.
# 9. Обміняйте значення, якщо x > y.
# 10. Перевірте, що після обміну сума лишається незмінною.

# %% [markdown]
# ## Висновок

# %% [markdown]
# > В цій ...
